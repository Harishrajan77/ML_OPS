# %%
import pandas as pd
df = pd.read_csv('parking_dataset.csv')
df.head()
df = pd.get_dummies(
    df,
    columns=[
        'Weather',
        'Traffic_Level',
        'Day_Type',
        'Vehicle_Type',
        'Location_Type'
    ],
    drop_first=True
)
print('============================================')
print(df.head())
print(df.shape)
# Out:
# ...
#              Timestamp Parking_Lot_ID  Total_Slots  Occupied_Slots  \
# 0  2026-02-12 12:36:00          PL012           90              35
# 1  2025-11-22 06:41:00          PL009          140              69
# 2  2026-02-13 23:57:00          PL006          160              90
# 3  2026-03-26 20:42:00          PL004          380             241
# 4  2026-01-19 00:03:00          PL003          260             104
#
#    Available_Slots  Occupancy_Rate  Vehicle_Count  Entry_Count  Exit_Count  \
# 0               55           38.89             50           13           9
# 1               71           49.29             78            8           8
# 2               70           56.25            102            4          10
# 3              139           63.42            308           34          84
# 4              156           40.00            119           16           8
#
#    Congestion_Status  ...  Day_Type_Weekend  Vehicle_Type_Bus  \
# ...
